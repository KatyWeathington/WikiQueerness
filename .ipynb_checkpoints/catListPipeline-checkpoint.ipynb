# %%
import numpy as np
import pandas as pd
import re

pd.options.display.max_columns = 100
idx = pd.IndexSlice

# %matplotlib inline
import matplotlib.pyplot as pt
import seaborn as sb
sb.set_style('whitegrid')

import wikifunctions as wf

import requests, json, re, time, os, pprint

path = 'catlists\\'
from datetime import datetime
from bs4 import BeautifulSoup
from urllib.parse import unquote, quote
from copy import deepcopy

# %%
#set up an empty cat-list pair legend
#df=pd.DataFrame(columns=['category','list','suffixes'])
#df.head()
#df.to_csv(path+'keyPairs.csv',index=False)

# %%
def get_list(listName):
    l=listName.replace(' ','_')
    #df=pd.DataFrame()
    r = requests.get('https://en.wikipedia.org/wiki/'+str(l))
    con = r.content
    #print(con)
    df = pd.read_html(con)
    df=df[0]
    #df.to_csv(path+l+'.csv')
    df['inList']=listName
    df['listLink']='https://en.wikipedia.org/wiki/'+str(l)
    return df

# %%
def standardizeLists(df):
    #name
    dz=pd.DataFrame(columns=['name'])
    try:
        dz['name']=df['Name']
    except:
        print(df.head())
        return 
    #birth and/or death years
    try:
        dz['LGBTQ Identity']=df['Sexual orientation and/or gender identity']
    except:
        try:
            dz['LGBTQ Identity']=df['Sexual orientation and/or gender identity[2]']
        except:
            pass    
    try:
        dz['years']=df['Dates']
    except:
        try:
            dz['years']=df['Birth year']
        except:
            try:
                dz['years']=df['Lifetime']
            except:
                try:
                    dz['years']=df['Lifetime[1]']
                except:
                    pass
    try:
        dz['years'].apply(lambda s:s.strip('b.'))
    except:
        pass
    #nationality
    try:
        dz['country']=df['Nationality']
    except:
        try:
            dz['country']=df['Country']
        except:
            pass
    #pronouns maybe
    try:
        dz['pronouns']=df['Pronouns']
    except:
        pass
    #misc info
    try:
        dz['misc']=df['Comments']
    except:
        try:
            dz['misc']=df['Notable as']
        except:
            try:
                dz['misc']=df['Notes']
            except:
                pass
    dz['inList']=df['inList']
    dz['listLink']=df['listLink']
    
    return dz

# %%
def get_catMembers(categoryName, d=3):
    c=categoryName.replace(' ','_')
    catMembers = wf.get_category_members('Category:'+c,
                                        depth=d)
    
    df=pd.DataFrame()
    df['name']=catMembers
    df['wikiLink']=df['name'].apply(lambda s: 'https://en.wikipedia.org/wiki/'+str(s.replace(',','').replace(' ','_')))
    df['inCategory']=categoryName
    return df

# %%
#d=get_list('List of transgender people')
#d=standardizeLists(d)
#d.head()

# %%
def diffListCat(categoryName,listName,suffixes=[]):
    a=get_catMembers(categoryName)
    b=get_list(listName,suffixes)
    b=standardizeLists(b)
    try:
        c=list(set(b['name']) and set(a['name']))
        print(c)
    except:
        return
    notInList=b[b['name'] not in c]
    notInCategory=a[a['name'] not in c]
    notInList['addToList']=listName
    notInCategory['addToCategory']=categoryName
    return [notInList, notInCategory]

# %%
df=pd.read_csv(path+'keyPairs.csv',keep_default_na=False,index_col=False)
addToList=pd.DataFrame()
addToCat=pd.DataFrame()
for index, row in df.iterrows():
    try:
        ls,ct=diffListCat(categoryName=row[0],listName=row[1],suffixes=row[2])
        addToList.append(ls)
        addToCat.append(ct)
    except:
        pass

# %%
addToList.to_csv('addToList.csv',index=False)
addToCat.to_csv('addToCat.csv',index=False)

# %%
#testing the get_list() method
ls=get_list('List of LGBT writers')
ls.head()
# Out:
#                          Name   Lifetime        Nationality  \
# 0         Caio Fernando Abreu  1948–1996          Brazilian
# 1               Barry D. Adam    b. 1952           Canadian
# 2                  Evan Adams    b. 1966           Canadian
# 3  Nathan Niigan Noodin Adler       b. ?           Canadian
# 4                  Etel Adnan    b. 1925  Lebanese-American
#
#                   Genre                                      Notable works  \
# 0  short stories, plays   Morangos Mofados, dragões não conhecem o paraíso
# 1               scholar  The Rise of a Gay and Lesbian Movement, The Gl...
# 2            playwright  Dreams of Sheep, Snapshots, Dirty Dog River an...
# 3                horror                                  Wrist, Ghost Lake
# 4                  poet                                        Sea and Fog
#
#   References                inList  \
# 0        [1]  List of LGBT writers
# 1        [2]  List of LGBT writers
# 2        [3]  List of LGBT writers
# 3        [4]  List of LGBT writers
# 4        [5]  List of LGBT writers
#
#                                             listLink
# 0  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 1  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 2  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 3  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 4  https://en.wikipedia.org/wiki/List_of_LGBT_wri...

# %%
#testing the standardizeLists() method
standardized_ls=standardizeLists(ls)
standardized_ls.head()
# Out:
#                          name      years            country  \
# 0         Caio Fernando Abreu  1948–1996          Brazilian
# 1               Barry D. Adam    b. 1952           Canadian
# 2                  Evan Adams    b. 1966           Canadian
# 3  Nathan Niigan Noodin Adler       b. ?           Canadian
# 4                  Etel Adnan    b. 1925  Lebanese-American
#
#                  inList                                           listLink
# 0  List of LGBT writers  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 1  List of LGBT writers  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 2  List of LGBT writers  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 3  List of LGBT writers  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 4  List of LGBT writers  https://en.wikipedia.org/wiki/List_of_LGBT_wri...

# %%
cm=get_catMembers('LGBT writers')
cm.head()
# Out:
#                    name                                           wikiLink  \
# 0  List of LGBT writers  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 1           Rob Astbury          https://en.wikipedia.org/wiki/Rob_Astbury
# 2            Anton Enus           https://en.wikipedia.org/wiki/Anton_Enus
# 3        Narelda Jacobs       https://en.wikipedia.org/wiki/Narelda_Jacobs
# 4     Patricia Karvelas    https://en.wikipedia.org/wiki/Patricia_Karvelas
#
#      inCategory
# 0  LGBT writers
# 1  LGBT writers
# 2  LGBT writers
# 3  LGBT writers
# 4  LGBT writers

# %%
z=standardized_ls.merge(cm, on='name', how='inner').drop_duplicates()

# %%
notInCategory=standardized_ls[~standardized_ls.name.isin(cm['name'].unique())]
notInCategory.head()
# Out:
#                 name      years           country                inList  \
# 6      Magaly Alabau    b. 1945    Cuban American  List of LGBT writers
# 15       Lisa Alther    b. 1944          American  List of LGBT writers
# 21  Patrick Anderson  1915–1979  English/Canadian  List of LGBT writers
# 22   Albalucía Angel    b. 1939         Colombian  List of LGBT writers
# 23         Núria Añó    b. 1973           Spanish  List of LGBT writers
#
#                                              listLink
# 6   https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 15  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 21  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 22  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 23  https://en.wikipedia.org/wiki/List_of_LGBT_wri...

# %%
notInList=cm[~cm.name.isin(standardized_ls['name'].unique())]
notInList.head()
# Out:
#                    name                                           wikiLink  \
# 0  List of LGBT writers  https://en.wikipedia.org/wiki/List_of_LGBT_wri...
# 1           Rob Astbury          https://en.wikipedia.org/wiki/Rob_Astbury
# 2            Anton Enus           https://en.wikipedia.org/wiki/Anton_Enus
# 3        Narelda Jacobs       https://en.wikipedia.org/wiki/Narelda_Jacobs
# 4     Patricia Karvelas    https://en.wikipedia.org/wiki/Patricia_Karvelas
#
#      inCategory
# 0  LGBT writers
# 1  LGBT writers
# 2  LGBT writers
# 3  LGBT writers
# 4  LGBT writers

# %%
df=pd.read_csv(path+'keyPairs.csv',keep_default_na=False,index_col=False)
addToList=pd.DataFrame()
addToCat=pd.DataFrame()
for index, row in df.iterrows():
    print(row['list'])
# Out:
# List of LGBT sportspeople
# List of LGBT African Americans
# List of LGBT writers
# List of LGBT artists
# List of LGBT artists
